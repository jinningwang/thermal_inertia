# %% [markdown]
# # Case

# %%
import numpy as np
import pandas as pd

from typing import Dict

import andes
import ams

# %%
# %matplotlib inline

# %%
# !ams misc --version
# Out:
# Python   3.12.0
# ams      1.0.7
# andes    1.9.3.post6+g518882a0
# numpy    2.0.2
# cvxpy    1.6.0
# solvers  CLARABEL, ECOS, ECOS_BB,
#          GUROBI, HIGHS, MOSEK, OSQP,
#          PIQP, SCIP, SCIPY, SCS

# %%
andes.config_logger(stream_level=30)
ams.config_logger(stream_level=20)

# %%
mpc5 = ams.io.matpower.m2mpc("./Texas2k/Texas2k_case5.m")

# %% [markdown]
# Tune the parameters

# %%
gencost = np.concatenate((mpc5['gencost'][:, 0:4],
                          np.zeros((mpc5["gencost"].shape[0], 4))),
                         axis=1)

gencost[:, 3] = 2  # type 2 gencost
gencost[:, 5] = 0.0  # c2
gencost[:, 6] = mpc5['gencost'][:, 5]  # c1
gencost[:, 7] = mpc5['gencost'][:, 5]  # c0

# scale up some line thermal limits
line_id = np.array([343,  344, 2324])
branch = mpc5['branch'].copy()
branch[:, 5] = 1.1 * mpc5['branch'][:, 5]

mpc_out = mpc5.copy()
mpc_out['gencost'] = gencost
mpc_out['branch'] = branch

# %%
sp = ams.system.System()
ams.io.matpower.mpc2system(mpc_out, sp)

sp.setup()
# Out:
# Zero Line parameters detected, adjusted to default values: rate_b, rate_c, amax, amin.
# System set up in 0.0079 seconds.
# True

# %% [markdown]
# Export to JSON format.

# %%
# ams.io.json.write(sp, './Texas2k/Texas2k_case5.json', overwrite=True)

# %%
sp.DCOPF.run(solver='PIQP')
# Out:
# Building system matrices
# Parsing OModel for <DCOPF>
# Evaluating OModel for <DCOPF>
# Finalizing OModel for <DCOPF>
# <DCOPF> initialized in 0.5194 seconds.
# <DCOPF> solved as optimal in 0.1931 seconds, converged in 14 iterations with PIQP.
# True

# %%
dyr = andes.io.psse._read_dyr_dict("./Texas2k/Texas2k.dyr")

# %% [markdown]
# In ANDES v1.9.3, some unsupported models can be replaced with supported models.
#
# [GGOV1](https://www.powerworld.com/WebHelp/Content/TransientModels_HTML/Governor%20GGOV1%20and%20GGOV1D.htm) -> TGOV1
#
# [PSS2A](https://www.powerworld.com/WebHelp/Content/TransientModels_HTML/Stabilizer%20PSS2A.htm) -> [ST2CUT](https://www.powerworld.com/WebHelp/Content/TransientModels_HTML/Stabilizer%20ST2CUT.htm)
#
# [GENSAL](https://www.powerworld.com/WebHelp/Content/TransientModels_HTML/Generator%20Model%20GENSAL.htm) -> GENROU

# %%
sa = andes.system.System()

# %%
def write_dict_dyr(dyr_dict: Dict[str, pd.DataFrame], outfile: str):
    """
    Write a dictionary of dynamic models to a DYR file.

    This function takes a dictionary where the keys are model names (e.g., 'REGCA1', 'REECA1') 
    and the values are pandas DataFrames containing the model parameters. It writes the data 
    to a DYR file in the correct format, ensuring the following:
    - The first column (IBUS) is an integer representing the bus index.
    - The second column is the model name, enclosed in single quotes.
    - The third column (ID) is an integer representing the device index.
    - Remaining columns are the model parameters, written as space-separated values.
    - Each line ends with a trailing slash ('/').

    Models 'Toggle' are skipped during the writing process.

    Parameters:
    -----------
    dyr_dict : Dict[str, pd.DataFrame]
        A dictionary where each key is a model name and each value is a pandas DataFrame 
        containing the parameters for that model. The DataFrame must have the following structure:
        - Column 0: IBUS (integer)
        - Column 1: ID (integer)
        - Columns 2+: Model parameters (various types).
    
    outfile : str
        The path to the output DYR file where the formatted data will be written.

    Returns:
    --------
    None
        The function writes the data to the specified file and prints a success message.

    Notes:
    ------
    - The function skips models with the name 'Toggle' and prints a message for each skipped model.
    - A blank line is not added between models in the output file.
    - Ensure the input DataFrames are properly formatted to avoid runtime errors.

    Example:
    --------
    >>> dyr_dict = {
    ...     'REGCA1': pd.DataFrame([
    ...         [1004, 1, 1.0, 0.01, 10, 0.9, 0.5],
    ...         [1006, 1, 1.0, 0.02, 10, 0.9, 0.5]
    ...     ]),
    ...     'REECA1': pd.DataFrame([
    ...         [1004, 1, 0, 0, 1, 1, 1],
    ...         [1006, 1, 0, 0, 1, 1, 1]
    ...     ])
    ... }
    >>> write_dict_dyr(dyr_dict, './output.dyr')
    Data successfully written to ./output.dyr
    """
    with open(outfile, 'w') as f:
        for model_name, df in dyr_dict.items():
            if model_name in ['Toggle']:
                print(f"Skipped {model_name}")
                continue
            for _, row in df.iterrows():
                ibus = int(row.iloc[0])  # format IBUS as integer
                model = f"'{model_name}'"  # model name
                device_id = int(row.iloc[1])  # format ID as integer
                # format the rest parameters
                params = ' '.join(map(str, row.iloc[2:].values))
                # Combine all parts into a formatted line
                formatted_line = f"{ibus} {model} {device_id} {params} /"
                # Write the formatted line to the file
                f.write(formatted_line + '\n')

    print(f"Data successfully written to {outfile}")

# %%
# Duplicate supported models first
dyr_out = dict()

for mname in dyr.keys():
    # models to manually convert
    if mname in ['GGOV1', 'PSS2A', 'GENSAL']:
        continue
    # hard code to skip models as run into error in this case
    if mname in ['WTPTA1', 'WTTQA1', 'WTARA1']:
        continue
    dyr_out[mname] = dyr[mname].copy()

# GENSAL -> GENROU
GENROU_converted = dyr['GENSAL'].copy()
GENROU_converted[14] = sa.GENROU.S10.default
GENROU_converted[15] = sa.GENROU.S12.default
dyr_out['GENROU'] = pd.concat([dyr_out['GENROU'], GENROU_converted],
                              axis=0, ignore_index=True)

# PSS2A -> ST2CUT, there are 22 columns in ST2CUT
ST2CUT = pd.DataFrame()

ST2CUT[0] = dyr['PSS2A'][0]  # IBUS
ST2CUT[1] = dyr['PSS2A'][1]  # ID

ST2CUT[2] = dyr['PSS2A'][2]  # M, IC1 <- M, ICS1
ST2CUT[3] = dyr['PSS2A'][3]  # M+1, IB1 <- M+1, REMBUS1
ST2CUT[4] = dyr['PSS2A'][4]  # M+2, IB2 <- M+2, ICS2
ST2CUT[5] = dyr['PSS2A'][5]  # M+3, IB3 <- M+3, REMBUS2

ST2CUT[6] = 1  # J, K1 <- 1
# J+1, K2 <- J+6, Ks2 * J+7, Ks3
ST2CUT[7] = dyr['PSS2A'][14] * dyr['PSS2A'][15]
ST2CUT[8] = dyr['PSS2A'][10]  # J+2, T1 <- J+2, T6
ST2CUT[9] = dyr['PSS2A'][13]  # J+3, T2 <- J+5, T7
ST2CUT[10] = sa.ST2CUT.T3.default  # J+4, T3 <- default
ST2CUT[11] = sa.ST2CUT.T4.default  # J+5, T4 <- default
ST2CUT[12] = dyr['PSS2A'][19]  # J+6, T5 <- J+11, T1
ST2CUT[13] = dyr['PSS2A'][20]  # J+7, T6 <- J+12, T2
ST2CUT[14] = dyr['PSS2A'][21]  # J+8, T7 <- J+13, T3
ST2CUT[15] = dyr['PSS2A'][22]  # J+9, T8 <- J+14, T4
ST2CUT[16] = sa.ST2CUT.T9.default  # J+10, T9 <- default
ST2CUT[17] = ST2CUT[16]  # J+11, T10 <- copy of T9
ST2CUT[18] = dyr['PSS2A'][23]  # J+12, LSMAX <- J+15, VSTMAX
ST2CUT[19] = dyr['PSS2A'][24]  # J+13, LSMIN <- J+16, VSTMIN
ST2CUT[20] = sa.ST2CUT.VCU.default  # J+14, VCU <- default
ST2CUT[21] = sa.ST2CUT.VCL.default  # J+15, VCL <- default
dyr_out['ST2CUT'] = ST2CUT

# GGOV1 -> TGOV1, there are 9 columns in TGOV1
TGOV1_converted = pd.DataFrame()
TGOV1_converted[0] = dyr['GGOV1'][0]  # IBUS
TGOV1_converted[1] = dyr['GGOV1'][1]  # ID
TGOV1_converted[2] = dyr['GGOV1'][2]  # J, R <- J, r
TGOV1_converted[3] = dyr['GGOV1'][16]  # J+1, T1 <- J+15, Teng
TGOV1_converted[4] = sa.TGOV1.VMAX.default  # J+2, T2 <- J+16, Te
TGOV1_converted[5] = sa.TGOV1.VMIN.default  # J+2, T2 <- J+16, Te
TGOV1_converted[6] = dyr['GGOV1'][15]  # J+4, T2 <- J+14, Tc
TGOV1_converted[7] = dyr['GGOV1'][14]  # J+5, T3 <- J+13, Tb
TGOV1_converted[8] = dyr['GGOV1'][15]  # J+6, Dt <- J+20, Dm
dyr_out['TGOV1'] = TGOV1_converted

# %%
# NOTE: hard code to remove folowing renewable generation involved devices 
# if they connect at bus 5394, 5395, 7095, 7099

for mname, df in dyr_out.items():
    if mname in ['REGCA1', 'REECA1', 'REPCA1', 'WTPTA1', 'WTTQA1', 'WTARA1']:
        rows_to_drop = df[df[0].isin([5394, 5395, 7095, 7099])].index
        df.drop(rows_to_drop, inplace=True)
        dyr_out[mname] = df.reset_index(drop=True)

# %%
# # Write the original DYR file to sort it, without changing anything
# write_dict_dyr(dyr, './Texas2k/Texas2k_case5_sorted.dyr')

# Write the modified DYR file
write_dict_dyr(dyr_out, './Texas2k/Texas2k_case5_mod.dyr')
# Out:
# Data successfully written to ./Texas2k/Texas2k_case5_mod.dyr

# %%
sa0 = andes.load(
    "Texas2k/Texas2k_v33.raw",
    addfile="Texas2k/Texas2k_case5_mod.dyr",
    setup=False,
    no_output=True,
    )

# andes.io.xlsx.write(sa0, "Texas2k/Texas2k_case5_mod_syngen.xlsx", overwrite=True)
# Out:
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter GENROU.M corrected to 6
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Non-zero parameter REECA1.Vref1 corrected to 1.0
# Error: <REPCA1> cannot retrieve <bus1> from <ACLine> using <line>:
#   KeyError('Group <ACLine> does not contain device with idx=False')
# Error: <REPCA1> cannot retrieve <bus2> from <ACLine> using <line>:
#   KeyError('Group <ACLine> does not contain device with idx=False')
# Error: <REPCA1> cannot retrieve <r> from <ACLine> using <line>:
#   KeyError('Group <ACLine> does not contain device with idx=False')
# Error: <REPCA1> cannot retrieve <x> from <ACLine> using <line>:
#   KeyError('Group <ACLine> does not contain device with idx=False')

# %%
# manually assign line to REPCA1

ree = sa0.REPCA1.ree.v
reg = sa0.REECA1.get(src='reg', attr='v', idx=ree)
bus = sa0.REGCA1.get(src='bus', attr='v', idx=reg)
line1 = sa0.Line.find_idx(keys='bus1', values=bus, allow_none=True, default=None)
line2 = sa0.Line.find_idx(keys='bus2', values=bus, allow_none=True, default=None)
line = []
for l1, l2 in zip(line1, line2):
    if l1 is not None:
        line.append(l1)
    elif l2 is not None:
        line.append(l2)
    else:
        line.append(None)
sa0.REPCA1.line.v = line

# %%
sa0.setup()
# Out:
# True

# %%
sa0.PFlow.run()
# Out:
# True

# %%
_ = sa0.TDS.init()
# Out:
# GENROU (vf range) out of typical lower limit.
#
#     idx     | values | limit
# ------------+--------+------
#  GENROU_1   | 0      | 1
#  GENROU_2   | 0      | 1
#  GENROU_4   | 0      | 1
#  GENROU_5   | 0      | 1
#  GENROU_6   | 0      | 1
#  GENROU_7   | 0      | 1
#  GENROU_8   | 0      | 1
#  GENROU_11  | 0      | 1
#  GENROU_12  | 0      | 1
#  GENROU_13  | 0      | 1
#  GENROU_14  | 0      | 1
#  GENROU_15  | 0      | 1
#  GENROU_16  | 0      | 1
#  GENROU_17  | 0      | 1
#  GENROU_18  | 0      | 1
#  GENROU_19  | 0      | 1
#  GENROU_20  | 0      | 1
#  GENROU_21  | 0      | 1
#  GENROU_22  | 0      | 1
#  GENROU_23  | 0      | 1
#  GENROU_24  | 0      | 1
#  GENROU_26  | 0      | 1
#  GENROU_27  | 0      | 1
#  GENROU_28  | 0      | 1
#  GENROU_29  | 0      | 1
#  GENROU_30  | 0      | 1
#  GENROU_31  | 0      | 1
#  GENROU_32  | 0      | 1
#  GENROU_34  | 0      | 1
#  GENROU_35  | 0      | 1
#  GENROU_36  | 0      | 1
#  GENROU_37  | 0      | 1
#  GENROU_38  | 0      | 1
#  GENROU_39  | 0      | 1
#  GENROU_40  | 0      | 1
#  GENROU_41  | 0      | 1
#  GENROU_42  | 0      | 1
#  GENROU_43  | 0      | 1
#  GENROU_47  | 0      | 1
#  GENROU_48  | 0      | 1
#  GENROU_49  | 0      | 1
#  GENROU_50  | 0      | 1
#  GENROU_54  | 0      | 1
#  GENROU_56  | 0      | 1
#  GENROU_59  | 0      | 1
#  GENROU_60  | 0      | 1
#  GENROU_61  | 0      | 1
#  GENROU_62  | 0      | 1
#  GENROU_63  | 0      | 1
#  GENROU_64  | 0      | 1
#  GENROU_65  | 0      | 1
#  GENROU_67  | 0      | 1
#  GENROU_69  | 0      | 1
#  GENROU_71  | 0      | 1
#  GENROU_72  | 0      | 1
#  GENROU_73  | 0      | 1
#  GENROU_74  | 0      | 1
#  GENROU_75  | 0      | 1
#  GENROU_76  | 0      | 1
#  GENROU_77  | 0      | 1
#  GENROU_79  | 0      | 1
#  GENROU_80  | 0      | 1
#  GENROU_81  | 0      | 1
#  GENROU_82  | 0      | 1
#  GENROU_83  | 0      | 1
#  GENROU_84  | 0      | 1
#  GENROU_85  | 0      | 1
#  GENROU_86  | 0      | 1
#  GENROU_89  | 0      | 1
#  GENROU_90  | 0      | 1
#  GENROU_91  | 0      | 1
#  GENROU_92  | 0      | 1
#  GENROU_93  | 0      | 1
#  GENROU_94  | 0      | 1
#  GENROU_95  | 0      | 1
#  GENROU_97  | 0      | 1
#  GENROU_98  | 0      | 1
#  GENROU_99  | 0      | 1
#  GENROU_100 | 0      | 1
#  GENROU_102 | 0      | 1
#  GENROU_104 | 0      | 1
#  GENROU_105 | 0      | 1
#  GENROU_107 | 0      | 1
#  GENROU_108 | 0      | 1
#  GENROU_109 | 0      | 1
#  GENROU_110 | 0      | 1
#  GENROU_112 | 0      | 1
#  GENROU_114 | 0      | 1
#  GENROU_115 | 0      | 1
#  GENROU_119 | 0      | 1
#  GENROU_120 | 0      | 1
#  GENROU_122 | 0      | 1
#  GENROU_129 | 0      | 1
#  GENROU_130 | 0      | 1
#  GENROU_135 | 0      | 1
#  GENROU_136 | 0.730  | 1
#  GENROU_138 | 0      | 1
#  GENROU_139 | 0.974  | 1
#  GENROU_140 | 0.868  | 1
#  GENROU_152 | 0      | 1
#  GENROU_153 | 0      | 1
#  GENROU_154 | 0      | 1
#  GENROU_155 | 0      | 1
#  GENROU_156 | 0      | 1
#  GENROU_157 | 0      | 1
#  GENROU_159 | 0      | 1
#  GENROU_160 | 0      | 1
#  GENROU_163 | 0      | 1
#  GENROU_164 | 0      | 1
#  GENROU_165 | 0      | 1
#  GENROU_166 | 0      | 1
#  GENROU_168 | 0      | 1
#  GENROU_169 | 0      | 1
#  GENROU_170 | 0      | 1
#  GENROU_171 | 0      | 1
#  GENROU_172 | 0      | 1
#  GENROU_173 | 0      | 1
#  GENROU_175 | 0      | 1
#  GENROU_176 | 0      | 1
#  GENROU_177 | 0      | 1
#  GENROU_178 | 0      | 1
#  GENROU_179 | 0      | 1
#  GENROU_181 | 0      | 1
#  GENROU_182 | 0      | 1
#  GENROU_183 | 0.554  | 1
#  GENROU_185 | 0      | 1
#  GENROU_186 | 0      | 1
#  GENROU_187 | 0      | 1
#  GENROU_189 | 0      | 1
#  GENROU_190 | 0      | 1
#  GENROU_191 | 0      | 1
#  GENROU_192 | 0      | 1
#  GENROU_193 | 0      | 1
#  GENROU_195 | 0      | 1
#  GENROU_196 | 0      | 1
#  GENROU_197 | 0      | 1
#  GENROU_200 | 0      | 1
#  GENROU_201 | 0      | 1
#  GENROU_202 | 0      | 1
#  GENROU_203 | 0      | 1
#  GENROU_204 | 0      | 1
#  GENROU_205 | 0      | 1
#  GENROU_206 | 0      | 1
#  GENROU_207 | 0      | 1
#  GENROU_208 | 0      | 1
#  GENROU_209 | 0      | 1
#  GENROU_211 | 0      | 1
#  GENROU_212 | 0      | 1
#  GENROU_214 | 0      | 1
#  GENROU_215 | 0      | 1
#  GENROU_216 | 0      | 1
#  GENROU_217 | 0      | 1
#  GENROU_218 | 0.636  | 1
#  GENROU_219 | 0      | 1
#  GENROU_220 | 0      | 1
#  GENROU_221 | 0      | 1
#  GENROU_222 | 0      | 1
#  GENROU_223 | 0      | 1
#  GENROU_224 | 0      | 1
#  GENROU_225 | 0      | 1
#  GENROU_226 | 0      | 1
#  GENROU_227 | 0      | 1
#  GENROU_229 | 0      | 1
#  GENROU_230 | 0      | 1
#  GENROU_231 | 0      | 1
#  GENROU_232 | 0      | 1
#  GENROU_233 | 0      | 1
#  GENROU_235 | 0      | 1
#  GENROU_236 | 0      | 1
#  GENROU_237 | 0      | 1
#  GENROU_238 | 0      | 1
#  GENROU_240 | 0      | 1
#  GENROU_241 | 0      | 1
#  GENROU_242 | 0      | 1
#  GENROU_243 | 0      | 1
#  GENROU_244 | 0      | 1
#  GENROU_245 | 0      | 1
#  GENROU_246 | 0      | 1
#  GENROU_247 | 0      | 1
#  GENROU_249 | 0      | 1
#  GENROU_250 | 0      | 1
#  GENROU_251 | 0      | 1
#  GENROU_255 | 0      | 1
#  GENROU_256 | 0      | 1
#  GENROU_257 | 0      | 1
#  GENROU_258 | 0      | 1
#  GENROU_259 | 0      | 1
#  GENROU_260 | 0      | 1
#  GENROU_262 | 0      | 1
#  GENROU_263 | 0      | 1
#  GENROU_264 | 0      | 1
#  GENROU_265 | 0      | 1
#  GENROU_266 | 0      | 1
#  GENROU_267 | 0      | 1
#  GENROU_268 | 0      | 1
#  GENROU_269 | 0      | 1
#  GENROU_270 | 0      | 1
#  GENROU_271 | 0      | 1
#  GENROU_272 | 0      | 1
#  GENROU_273 | 0      | 1
#  GENROU_274 | 0      | 1
#  GENROU_275 | 0      | 1
#  GENROU_276 | 0      | 1
#  GENROU_277 | 0      | 1
#  GENROU_278 | 0      | 1
#  GENROU_279 | 0      | 1
#  GENROU_280 | 0      | 1
#  GENROU_281 | 0      | 1
#  GENROU_282 | 0      | 1
#  GENROU_283 | 0      | 1
#  GENROU_284 | 0      | 1
#  GENROU_285 | 0      | 1
#  GENROU_286 | 0      | 1
#  GENROU_287 | 0      | 1
#  GENROU_288 | 0      | 1
#  GENROU_289 | 0      | 1
#  GENROU_290 | 0      | 1
#  GENROU_291 | 0      | 1
#  GENROU_292 | 0      | 1
#  GENROU_293 | 0      | 1
#  GENROU_295 | 0      | 1
#  GENROU_297 | 0      | 1
#  GENROU_298 | 0      | 1
#  GENROU_299 | 0      | 1
#  GENROU_300 | 0      | 1
#  GENROU_301 | 0      | 1
#  GENROU_303 | 0      | 1
#  GENROU_304 | 0      | 1
#  GENROU_305 | 0      | 1
#  GENROU_306 | 0      | 1
#  GENROU_307 | 0      | 1
#  GENROU_309 | 0      | 1
#  GENROU_310 | 0      | 1
#  GENROU_311 | 0      | 1
#  GENROU_312 | 0      | 1
#  GENROU_313 | 0      | 1
#  GENROU_314 | 0      | 1
#  GENROU_315 | 0.743  | 1
#  GENROU_316 | 0.272  | 1
#  GENROU_318 | 0      | 1
#  GENROU_320 | 0      | 1
#  GENROU_321 | 0      | 1
#  GENROU_322 | 0      | 1
#  GENROU_323 | 0      | 1
#  GENROU_324 | 0      | 1
#  GENROU_325 | 0      | 1
#  GENROU_327 | 0      | 1
#  GENROU_328 | 0      | 1
#  GENROU_329 | 0      | 1
#  GENROU_330 | 0      | 1
#  GENROU_331 | 0      | 1
#  GENROU_332 | 0      | 1
#  GENROU_333 | 0      | 1
#  GENROU_334 | 0      | 1
#  GENROU_335 | 0      | 1
#  GENROU_336 | 0      | 1
#  GENROU_337 | 0      | 1
#  GENROU_338 | 0      | 1
#  GENROU_339 | 0      | 1
#  GENROU_340 | 0      | 1
#  GENROU_341 | 0      | 1
#  GENROU_345 | 0      | 1
#  GENROU_346 | 0      | 1
#  GENROU_347 | 0      | 1
#  GENROU_348 | 0      | 1
#  GENROU_349 | 0      | 1
#  GENROU_350 | -3.583 | 1
#  GENROU_351 | 0      | 1
#  GENROU_353 | 0      | 1
#  GENROU_355 | 0      | 1
#  GENROU_367 | 0      | 1
#  GENROU_368 | 0      | 1
#  GENROU_369 | 0      | 1
#  GENROU_370 | 0      | 1
#  GENROU_373 | 0      | 1
#  GENROU_374 | 0      | 1
#  GENROU_375 | 0      | 1
#  GENROU_376 | 0      | 1
#  GENROU_377 | 0      | 1
#  GENROU_378 | 0      | 1
#  GENROU_379 | 0      | 1
#  GENROU_380 | 0      | 1
#  GENROU_381 | 0      | 1
#  GENROU_382 | 0      | 1
#  GENROU_383 | 0      | 1
#  GENROU_384 | 0      | 1
#  GENROU_386 | 0      | 1
#  GENROU_387 | 0      | 1
#  GENROU_388 | 0      | 1
#  GENROU_389 | 0      | 1
#  GENROU_390 | 0      | 1
#  GENROU_391 | 0.811  | 1
#  GENROU_392 | 0      | 1
#  GENROU_393 | 0      | 1
#  GENROU_396 | 0      | 1
#  GENROU_398 | 0      | 1
#  GENROU_399 | 0      | 1
#  GENROU_401 | 0      | 1
#  GENROU_402 | 0      | 1
#  GENROU_404 | 0      | 1
#  GENROU_405 | 0      | 1
#  GENROU_406 | 0      | 1
#  GENROU_407 | 0      | 1
#  GENROU_408 | 0      | 1
#  GENROU_409 | 0      | 1
#  GENROU_410 | 0      | 1
#  GENROU_411 | 0      | 1
#  GENROU_412 | 0      | 1
#  GENROU_413 | 0      | 1
#  GENROU_414 | 0      | 1
#  GENROU_415 | 0      | 1
#  GENROU_416 | 0      | 1
#  GENROU_417 | 0      | 1
#  GENROU_418 | 0      | 1
#  GENROU_419 | 0      | 1
#  GENROU_420 | 0      | 1
#  GENROU_421 | 0      | 1
#  GENROU_422 | 0      | 1
#  GENROU_423 | 0      | 1
#  GENROU_424 | 0      | 1
#  GENROU_425 | 0      | 1
#  GENROU_426 | 0      | 1
#  GENROU_427 | 0      | 1
#  GENROU_428 | 0      | 1
#  GENROU_429 | 0      | 1
#  GENROU_430 | 0      | 1
#  GENROU_431 | 0      | 1
#  GENROU_432 | 0      | 1
#  GENROU_433 | 0      | 1
#  GENROU_434 | 0      | 1
#  GENROU_435 | 0      | 1
#
#
# GENROU (vf range) out of typical upper limit.
#
#     idx     | values  | limit
# ------------+---------+------
#  GENROU_121 | 103.664 | 5
#  GENROU_228 | 18.045  | 5
#  GENROU_344 | 5.602   | 5
#  GENROU_352 | 155.691 | 5
#  GENROU_356 | 21.120  | 5
#  GENROU_372 | 6.233   | 5
#
#
# GENROU (xl <= xd2) out of typical upper limit.
#
#     idx     | values | limit
# ------------+--------+------
#  GENROU_411 | 1.113  | 0.300
#  GENROU_412 | 0.211  | 0.035
#  GENROU_413 | 0.367  | 0.061
#  GENROU_414 | 1.872  | 0.535
#  GENROU_415 | 0.292  | 0.088
#  GENROU_416 | 0.261  | 0.038
#  GENROU_417 | 5.215  | 1.247
#  GENROU_418 | 0.174  | 0.032
#  GENROU_419 | 0.892  | 0.232
#  GENROU_420 | 0.113  | 0.021
#  GENROU_421 | 0.846  | 0.248
#  GENROU_422 | 0.700  | 0.175
#  GENROU_423 | 0.225  | 0.048
#  GENROU_424 | 0.072  | 0.016
#  GENROU_425 | 0.066  | 0.012
#  GENROU_426 | 0.093  | 0.026
#  GENROU_427 | 12.288 | 3.602
#  GENROU_428 | 5.026  | 0.926
#  GENROU_429 | 10.169 | 2.542
#  GENROU_430 | 6.614  | 1.720
#  GENROU_431 | 2.540  | 0.635
#  GENROU_432 | 4.675  | 1.299
#  GENROU_433 | 5.291  | 1.058
#  GENROU_434 | 5.291  | 1.058
#  GENROU_435 | 4.762  | 1.020
#
#
# /Users/jinningwang/.andes/pycode/ESST4B.py:89: RuntimeWarning: invalid value encountered in sqrt
#   return select([less_equal(IN, 0),less_equal(IN, 0.433),less_equal(IN, 0.75),less_equal(IN, 1),greater(IN, 1),__trues], [__ones,1 - 0.577*IN,sqrt(0.75 - IN**2),1.732 - 1.732*IN,__zeros,__zeros], default=nan)
# REGCA1.Iqout_lim: *not adjusted* limit <Iolim>
#
#     Idx     |  Input  | Old Limit
# ------------+---------+----------
#  REGCA1_13  | -0.349  | -0.059
#  REGCA1_51  | -3.282  | -0.311
#  REGCA1_91  | -5.681  | -2.580
#  REGCA1_115 | -8.785  | -1.220
#  REGCA1_171 | -1.459  | -1.427
#  REGCA1_187 | -0.255  | -0.163
#  REGCA1_189 | -1.104  | -0.682
#  REGCA1_209 | -2.223  | -1.435
#  REGCA1_211 | -6.282  | -0.081
#  REGCA1_229 | -8.371  | -5.068
#  REGCA1_246 | -0.505  | -0.325
#  REGCA1_249 | -22.536 | -0.413
#  REGCA1_267 | -1.752  | -1.631
#  REGCA1_273 | -59.078 | -0.272
#  REGCA1_274 | -2.139  | -0.272
#  REGCA1_284 | -0.623  | -0.491
#
#
# /Users/jinningwang/.andes/pycode/REECA1.py:225: RuntimeWarning: invalid value encountered in divide
#   return (-Iq1 + Iq2)/(-Vq1 + Vq2)
# /Users/jinningwang/.andes/pycode/REECA1.py:229: RuntimeWarning: invalid value encountered in divide
#   return (-Iq2 + Iq3)/(-Vq2 + Vq3)
# /Users/jinningwang/.andes/pycode/REECA1.py:233: RuntimeWarning: invalid value encountered in divide
#   return (-Iq3 + Iq4)/(-Vq3 + Vq4)
# /Users/jinningwang/.andes/pycode/REECA1.py:241: RuntimeWarning: invalid value encountered in divide
#   return (-Ip1 + Ip2)/(-Vp1 + Vp2)
# /Users/jinningwang/.andes/pycode/REECA1.py:245: RuntimeWarning: invalid value encountered in divide
#   return (-Ip2 + Ip3)/(-Vp2 + Vp3)
# /Users/jinningwang/.andes/pycode/REECA1.py:249: RuntimeWarning: invalid value encountered in divide
#   return (-Ip3 + Ip4)/(-Vp3 + Vp4)
# REECA1.PIQ_lim: *not adjusted* limit <VMIN>
#
#     Idx     |  Input  | Old Limit
# ------------+---------+----------
#  REECA1_2   | -0.001  | 0.900
#  REECA1_3   | 0.180   | 0.900
#  REECA1_4   | 0       | 0.900
#  REECA1_5   | 0.010   | 0.900
#  REECA1_6   | 0.853   | 0.900
#  REECA1_7   | 0.189   | 0.900
#  REECA1_8   | 0.254   | 0.900
#  REECA1_9   | 0.287   | 0.900
#  REECA1_10  | 0       | 0.900
#  REECA1_11  | -0.247  | 0.900
#  REECA1_12  | 0       | 0.900
#  REECA1_13  | 0.489   | 0.900
#  REECA1_15  | 0       | 0.900
#  REECA1_16  | 0.052   | 0.900
#  REECA1_17  | -5.055  | 0.900
#  REECA1_18  | 0       | 0.900
#  REECA1_19  | 0.011   | 0.900
#  REECA1_20  | 0       | 0.900
#  REECA1_21  | 0.015   | 0.900
#  REECA1_22  | -3.773  | 0.900
#  REECA1_23  | 0       | 0.900
#  REECA1_25  | 0.764   | 0.900
#  REECA1_26  | 0       | 0.900
#  REECA1_27  | 0.150   | 0.900
#  REECA1_28  | 0       | 0.900
#  REECA1_30  | 0       | 0.900
#  REECA1_31  | 0       | 0.900
#  REECA1_32  | 0       | 0.900
#  REECA1_33  | 0       | 0.900
#  REECA1_34  | 0       | 0.900
#  REECA1_35  | 0       | 0.900
#  REECA1_36  | 0       | 0.900
#  REECA1_37  | 0.261   | 0.900
#  REECA1_38  | -0.767  | 0.900
#  REECA1_39  | 0       | 0.900
#  REECA1_40  | 0       | 0.900
#  REECA1_42  | 0       | 0.900
#  REECA1_43  | 0       | 0.900
#  REECA1_44  | 0.354   | 0.900
#  REECA1_45  | 0.159   | 0.900
#  REECA1_46  | -0.001  | 0.900
#  REECA1_47  | 0.132   | 0.900
#  REECA1_48  | 0.291   | 0.900
#  REECA1_49  | 0.075   | 0.900
#  REECA1_52  | 0       | 0.900
#  REECA1_53  | 0.263   | 0.900
#  REECA1_54  | 0.202   | 0.900
#  REECA1_55  | 0.438   | 0.900
#  REECA1_56  | 0       | 0.900
#  REECA1_57  | 0       | 0.900
#  REECA1_58  | 0.371   | 0.900
#  REECA1_59  | 0.528   | 0.900
#  REECA1_60  | 0.328   | 0.900
#  REECA1_61  | 0.540   | 0.900
#  REECA1_62  | 0.077   | 0.900
#  REECA1_63  | 0       | 0.900
#  REECA1_64  | 0       | 0.900
#  REECA1_65  | -0.239  | 0.900
#  REECA1_66  | -0.130  | 0.900
#  REECA1_67  | 0       | 0.900
#  REECA1_68  | 0.083   | 0.900
#  REECA1_69  | -0.150  | 0.900
#  REECA1_70  | 0       | 0.900
#  REECA1_71  | 0       | 0.900
#  REECA1_72  | -1.041  | 0.900
#  REECA1_75  | -0.151  | 0.900
#  REECA1_76  | -1.450  | 0.900
#  REECA1_77  | 0       | 0.900
#  REECA1_78  | 0.302   | 0.900
#  REECA1_79  | 0.554   | 0.900
#  REECA1_80  | 0.513   | 0.900
#  REECA1_81  | 0       | 0.900
#  REECA1_82  | 0       | 0.900
#  REECA1_83  | 0.009   | 0.900
#  REECA1_84  | 0       | 0.900
#  REECA1_85  | 0       | 0.900
#  REECA1_86  | 0       | 0.900
#  REECA1_87  | 0       | 0.900
#  REECA1_88  | 0.002   | 0.900
#  REECA1_89  | 0       | 0.900
#  REECA1_90  | -0.095  | 0.900
#  REECA1_92  | -0.104  | 0.900
#  REECA1_93  | 0.005   | 0.900
#  REECA1_94  | -0.061  | 0.900
#  REECA1_95  | -0.000  | 0.900
#  REECA1_96  | 0.002   | 0.900
#  REECA1_97  | 0.005   | 0.900
#  REECA1_98  | -0.576  | 0.900
#  REECA1_99  | 0       | 0.900
#  REECA1_100 | 0.131   | 0.900
#  REECA1_101 | -3.833  | 0.900
#  REECA1_102 | 0       | 0.900
#  REECA1_103 | 0.280   | 0.900
#  REECA1_104 | 0.522   | 0.900
#  REECA1_105 | 0.406   | 0.900
#  REECA1_106 | 0       | 0.900
#  REECA1_107 | 0.031   | 0.900
#  REECA1_108 | 0.005   | 0.900
#  REECA1_109 | -0.138  | 0.900
#  REECA1_110 | 0       | 0.900
#  REECA1_111 | 0       | 0.900
#  REECA1_112 | 0       | 0.900
#  REECA1_113 | 0       | 0.900
#  REECA1_114 | -1.414  | 0.900
#  REECA1_115 | 0       | 0.900
#  REECA1_116 | 0       | 0.900
#  REECA1_117 | 0       | 0.900
#  REECA1_118 | -0.523  | 0.900
#  REECA1_119 | 0       | 0.900
#  REECA1_120 | -72.558 | 0.900
#  REECA1_121 | 0.806   | 0.900
#  REECA1_122 | 0       | 0.900
#  REECA1_123 | 0       | 0.900
#  REECA1_124 | 0       | 0.900
#  REECA1_125 | 0       | 0.900
#  REECA1_126 | 0       | 0.900
#  REECA1_127 | 0       | 0.900
#  REECA1_128 | 0       | 0.900
#  REECA1_129 | 0       | 0.900
#  REECA1_130 | 0       | 0.900
#  REECA1_131 | 0       | 0.900
#  REECA1_132 | -2.477  | 0.900
#  REECA1_133 | 0       | 0.900
#  REECA1_134 | 0.276   | 0.900
#  REECA1_135 | 0       | 0.900
#  REECA1_136 | -0.022  | 0.900
#  REECA1_137 | -0.092  | 0.900
#  REECA1_138 | 0       | 0.900
#  REECA1_139 | 0.872   | 0.900
#  REECA1_140 | 0       | 0.900
#  REECA1_141 | 0       | 0.900
#  REECA1_142 | -0.335  | 0.900
#  REECA1_143 | 0       | 0.900
#  REECA1_144 | 0       | 0.900
#  REECA1_145 | 0       | 0.900
#  REECA1_146 | 0       | 0.900
#  REECA1_147 | 0       | 0.900
#  REECA1_148 | 0       | 0.900
#  REECA1_150 | 0       | 0.900
#  REECA1_151 | 0       | 0.900
#  REECA1_152 | 0.063   | 0.900
#  REECA1_153 | 0.226   | 0.900
#  REECA1_154 | 0.336   | 0.900
#  REECA1_155 | 0       | 0.900
#  REECA1_156 | 0       | 0.900
#  REECA1_157 | -0.032  | 0.900
#  REECA1_158 | 0       | 0.900
#  REECA1_159 | 0       | 0.900
#  REECA1_160 | 0.513   | 0.900
#  REECA1_162 | -3.585  | 0.900
#  REECA1_163 | -3.286  | 0.900
#  REECA1_164 | 0       | 0.900
#  REECA1_166 | 0       | 0.900
#  REECA1_167 | -0.168  | 0.900
#  REECA1_169 | 0.532   | 0.900
#  REECA1_170 | 0       | 0.900
#  REECA1_171 | 0       | 0.900
#  REECA1_174 | 0       | 0.900
#  REECA1_175 | 0       | 0.900
#  REECA1_176 | 0       | 0.900
#  REECA1_177 | 0.150   | 0.900
#  REECA1_178 | 0.389   | 0.900
#  REECA1_179 | 0.325   | 0.900
#  REECA1_180 | 0       | 0.900
#  REECA1_181 | 0.664   | 0.900
#  REECA1_183 | -1.764  | 0.900
#  REECA1_184 | 0.351   | 0.900
#  REECA1_185 | -0.111  | 0.900
#  REECA1_187 | 0.433   | 0.900
#  REECA1_188 | 0       | 0.900
#  REECA1_190 | -0.800  | 0.900
#  REECA1_191 | 0.008   | 0.900
#  REECA1_192 | 0.000   | 0.900
#  REECA1_193 | 0.003   | 0.900
#  REECA1_194 | 0.001   | 0.900
#  REECA1_195 | 0.008   | 0.900
#  REECA1_196 | 0.004   | 0.900
#  REECA1_197 | -0.609  | 0.900
#  REECA1_198 | 0       | 0.900
#  REECA1_199 | -0.376  | 0.900
#  REECA1_202 | 0       | 0.900
#  REECA1_203 | -1.970  | 0.900
#  REECA1_204 | 0       | 0.900
#  REECA1_205 | 0.378   | 0.900
#  REECA1_206 | -0.027  | 0.900
#  REECA1_208 | -4.135  | 0.900
#  REECA1_210 | -0.072  | 0.900
#  REECA1_211 | 0       | 0.900
#  REECA1_213 | 0       | 0.900
#  REECA1_214 | -0.094  | 0.900
#  REECA1_215 | 0.093   | 0.900
#  REECA1_216 | 0       | 0.900
#  REECA1_217 | 0       | 0.900
#  REECA1_218 | 0       | 0.900
#  REECA1_219 | 0       | 0.900
#  REECA1_221 | 0.078   | 0.900
#  REECA1_222 | 0       | 0.900
#  REECA1_224 | -0.378  | 0.900
#  REECA1_225 | 0       | 0.900
#  REECA1_227 | -0.364  | 0.900
#  REECA1_228 | -0.796  | 0.900
#  REECA1_229 | -0.009  | 0.900
#  REECA1_231 | -0.201  | 0.900
#  REECA1_232 | 0.524   | 0.900
#  REECA1_233 | 0       | 0.900
#  REECA1_234 | -0.024  | 0.900
#  REECA1_235 | 0       | 0.900
#  REECA1_236 | -0.686  | 0.900
#  REECA1_237 | 0       | 0.900
#  REECA1_238 | 0.106   | 0.900
#  REECA1_239 | 0.089   | 0.900
#  REECA1_240 | 0.168   | 0.900
#  REECA1_241 | -0.573  | 0.900
#  REECA1_242 | -2.184  | 0.900
#  REECA1_243 | -0.002  | 0.900
#  REECA1_244 | 0       | 0.900
#  REECA1_245 | 0       | 0.900
#  REECA1_246 | -0.129  | 0.900
#  REECA1_248 | 0.113   | 0.900
#  REECA1_249 | -0.217  | 0.900
#  REECA1_251 | 0.854   | 0.900
#  REECA1_252 | 0.594   | 0.900
#  REECA1_253 | -5.764  | 0.900
#  REECA1_254 | -5.232  | 0.900
#  REECA1_255 | -3.210  | 0.900
#  REECA1_256 | -5.102  | 0.900
#  REECA1_257 | -0.159  | 0.900
#  REECA1_258 | 0.340   | 0.900
#  REECA1_259 | -0.182  | 0.900
#  REECA1_260 | -0.208  | 0.900
#  REECA1_261 | 0       | 0.900
#  REECA1_262 | -0.295  | 0.900
#  REECA1_263 | -0.072  | 0.900
#  REECA1_264 | -0.183  | 0.900
#  REECA1_265 | 0.298   | 0.900
#  REECA1_266 | -0.333  | 0.900
#  REECA1_267 | 0.283   | 0.900
#  REECA1_269 | -0.332  | 0.900
#  REECA1_270 | -0.305  | 0.900
#  REECA1_271 | -0.059  | 0.900
#  REECA1_272 | 0       | 0.900
#  REECA1_276 | 0.260   | 0.900
#  REECA1_277 | 0.001   | 0.900
#  REECA1_278 | 0.000   | 0.900
#  REECA1_279 | 0.001   | 0.900
#  REECA1_280 | 0.000   | 0.900
#  REECA1_281 | 0.001   | 0.900
#  REECA1_282 | -0.170  | 0.900
#  REECA1_283 | 0       | 0.900
#  REECA1_284 | 0       | 0.900
#  REECA1_286 | 0       | 0.900
#  REECA1_287 | -0.986  | 0.900
#  REECA1_288 | 0.128   | 0.900
#  REECA1_289 | 0       | 0.900
#  REECA1_290 | -0.591  | 0.900
#  REECA1_291 | -0.260  | 0.900
#  REECA1_292 | -0.178  | 0.900
#  REECA1_293 | -0.245  | 0.900
#  REECA1_294 | -0.309  | 0.900
#  REECA1_295 | -0.826  | 0.900
#  REECA1_298 | 0.877   | 0.900
#  REECA1_299 | -0.153  | 0.900
#  REECA1_300 | 0.737   | 0.900
#  REECA1_301 | 0       | 0.900
#  REECA1_302 | -0.466  | 0.900
#
#
# REECA1.Vsel_lim: *not adjusted* limit <VMIN>
#
#     Idx     | Input  | Old Limit
# ------------+--------+----------
#  REECA1_211 | -5.282 | 0.900
#
#
# REECA1.PIV_lim: *not adjusted* limit <Iqmin>
#
#     Idx     |  Input  | Old Limit
# ------------+---------+----------
#  REECA1_4   | -0.256  | 0
#  REECA1_12  | -0.062  | 0
#  REECA1_15  | -0.330  | 0
#  REECA1_18  | -0.009  | 0
#  REECA1_20  | -0.061  | 0
#  REECA1_23  | -0.109  | 0
#  REECA1_28  | -0.151  | 0
#  REECA1_32  | -0.472  | 0
#  REECA1_39  | -0.787  | 0
#  REECA1_40  | -1.087  | 0
#  REECA1_43  | -0.147  | 0
#  REECA1_57  | -0.195  | 0
#  REECA1_63  | -0.385  | 0
#  REECA1_71  | -0.023  | 0
#  REECA1_82  | -0.137  | 0
#  REECA1_89  | -0.012  | 0
#  REECA1_91  | -4.318  | 0
#  REECA1_99  | -0.326  | 0
#  REECA1_102 | -0.216  | 0
#  REECA1_106 | -0.062  | 0
#  REECA1_115 | -8.785  | 0
#  REECA1_122 | -1.097  | 0
#  REECA1_123 | -0.336  | 0
#  REECA1_131 | -0.153  | 0
#  REECA1_135 | -0.019  | 0
#  REECA1_139 | -0.109  | 0
#  REECA1_146 | -0.008  | 0
#  REECA1_147 | -0.001  | 0
#  REECA1_149 | -0.286  | 0
#  REECA1_150 | -0.052  | 0
#  REECA1_151 | -0.094  | 0
#  REECA1_158 | -1.477  | 0
#  REECA1_164 | -0.455  | 0
#  REECA1_168 | -0.024  | 0
#  REECA1_171 | -1.459  | 0
#  REECA1_175 | -0.036  | 0
#  REECA1_176 | -0.442  | 0
#  REECA1_180 | -0.492  | 0
#  REECA1_188 | -0.628  | 0
#  REECA1_198 | -0.120  | 0
#  REECA1_216 | -0.346  | 0
#  REECA1_218 | -0.006  | 0
#  REECA1_219 | -0.003  | 0
#  REECA1_222 | -0.307  | 0
#  REECA1_225 | -0.079  | 0
#  REECA1_230 | -4.353  | 0
#  REECA1_232 | -0.147  | 0
#  REECA1_233 | -0.106  | 0
#  REECA1_237 | -0.670  | 0
#  REECA1_274 | -12.997 | 0
#  REECA1_283 | -0.487  | 0
#  REECA1_297 | -0.280  | 0
#  REECA1_301 | -0.505  | 0
#
#
# REECA1.IqHL_lim: *not adjusted* limit <Iqmin>
#
#     Idx     | Input  | Old Limit
# ------------+--------+----------
#  REECA1_211 | -6.282 | 0
#
#
# REGCA1.Iqout_lim out of limits <Iolim>
#
#     idx     | Flag | Input Value | Limit
# ------------+------+-------------+-------
#  REGCA1_13  | zl   | -0.349      | -0.059
#  REGCA1_51  | zl   | -3.282      | -0.311
#  REGCA1_91  | zl   | -5.681      | -2.580
#  REGCA1_115 | zl   | -8.785      | -1.220
#  REGCA1_171 | zl   | -1.459      | -1.427
#  REGCA1_187 | zl   | -0.255      | -0.163
#  REGCA1_189 | zl   | -1.104      | -0.682
#  REGCA1_209 | zl   | -2.223      | -1.435
#  REGCA1_211 | zl   | -6.282      | -0.081
#  REGCA1_229 | zl   | -8.371      | -5.068
#  REGCA1_246 | zl   | -0.505      | -0.325
#  REGCA1_249 | zl   | -22.536     | -0.413
#  REGCA1_267 | zl   | -1.752      | -1.631
#  REGCA1_273 | zl   | -59.078     | -0.272
#  REGCA1_274 | zl   | -2.139      | -0.272
#  REGCA1_284 | zl   | -0.623      | -0.491
#
#
# REECA1.PFlim out of limits <QMin>
#
#     idx     | Flag | Input Value | Limit
# ------------+------+-------------+-------
#  REECA1_211 | zl   | -6.282      | -0.436
#
#
# REECA1.PIQ_lim out of limits <VMIN>
#
#     idx     | Flag | Input Value | Limit
# ------------+------+-------------+------
#  REECA1_2   | zl   | -0.001      | 0.900
#  REECA1_3   | zl   | 0.180       | 0.900
#  REECA1_4   | zl   | 0           | 0.900
#  REECA1_5   | zl   | 0.010       | 0.900
#  REECA1_6   | zl   | 0.853       | 0.900
#  REECA1_7   | zl   | 0.189       | 0.900
#  REECA1_8   | zl   | 0.254       | 0.900
#  REECA1_9   | zl   | 0.287       | 0.900
#  REECA1_10  | zl   | 0           | 0.900
#  REECA1_11  | zl   | -0.247      | 0.900
#  REECA1_12  | zl   | 0           | 0.900
#  REECA1_13  | zl   | 0.489       | 0.900
#  REECA1_15  | zl   | 0           | 0.900
#  REECA1_16  | zl   | 0.052       | 0.900
#  REECA1_17  | zl   | -5.055      | 0.900
#  REECA1_18  | zl   | 0           | 0.900
#  REECA1_19  | zl   | 0.011       | 0.900
#  REECA1_20  | zl   | 0           | 0.900
#  REECA1_21  | zl   | 0.015       | 0.900
#  REECA1_22  | zl   | -3.773      | 0.900
#  REECA1_23  | zl   | 0           | 0.900
#  REECA1_25  | zl   | 0.764       | 0.900
#  REECA1_26  | zl   | 0           | 0.900
#  REECA1_27  | zl   | 0.150       | 0.900
#  REECA1_28  | zl   | 0           | 0.900
#  REECA1_30  | zl   | 0           | 0.900
#  REECA1_31  | zl   | 0           | 0.900
#  REECA1_32  | zl   | 0           | 0.900
#  REECA1_33  | zl   | 0           | 0.900
#  REECA1_34  | zl   | 0           | 0.900
#  REECA1_35  | zl   | 0           | 0.900
#  REECA1_36  | zl   | 0           | 0.900
#  REECA1_37  | zl   | 0.261       | 0.900
#  REECA1_38  | zl   | -0.767      | 0.900
#  REECA1_39  | zl   | 0           | 0.900
#  REECA1_40  | zl   | 0           | 0.900
#  REECA1_42  | zl   | 0           | 0.900
#  REECA1_43  | zl   | 0           | 0.900
#  REECA1_44  | zl   | 0.354       | 0.900
#  REECA1_45  | zl   | 0.159       | 0.900
#  REECA1_46  | zl   | -0.001      | 0.900
#  REECA1_47  | zl   | 0.132       | 0.900
#  REECA1_48  | zl   | 0.291       | 0.900
#  REECA1_49  | zl   | 0.075       | 0.900
#  REECA1_52  | zl   | 0           | 0.900
#  REECA1_53  | zl   | 0.263       | 0.900
#  REECA1_54  | zl   | 0.202       | 0.900
#  REECA1_55  | zl   | 0.438       | 0.900
#  REECA1_56  | zl   | 0           | 0.900
#  REECA1_57  | zl   | 0           | 0.900
#  REECA1_58  | zl   | 0.371       | 0.900
#  REECA1_59  | zl   | 0.528       | 0.900
#  REECA1_60  | zl   | 0.328       | 0.900
#  REECA1_61  | zl   | 0.540       | 0.900
#  REECA1_62  | zl   | 0.077       | 0.900
#  REECA1_63  | zl   | 0           | 0.900
#  REECA1_64  | zl   | 0           | 0.900
#  REECA1_65  | zl   | -0.239      | 0.900
#  REECA1_66  | zl   | -0.130      | 0.900
#  REECA1_67  | zl   | 0           | 0.900
#  REECA1_68  | zl   | 0.083       | 0.900
#  REECA1_69  | zl   | -0.150      | 0.900
#  REECA1_70  | zl   | 0           | 0.900
#  REECA1_71  | zl   | 0           | 0.900
#  REECA1_72  | zl   | -1.041      | 0.900
#  REECA1_75  | zl   | -0.151      | 0.900
#  REECA1_76  | zl   | -1.450      | 0.900
#  REECA1_77  | zl   | 0           | 0.900
#  REECA1_78  | zl   | 0.302       | 0.900
#  REECA1_79  | zl   | 0.554       | 0.900
#  REECA1_80  | zl   | 0.513       | 0.900
#  REECA1_81  | zl   | 0           | 0.900
#  REECA1_82  | zl   | 0           | 0.900
#  REECA1_83  | zl   | 0.009       | 0.900
#  REECA1_84  | zl   | 0           | 0.900
#  REECA1_85  | zl   | 0           | 0.900
#  REECA1_86  | zl   | 0           | 0.900
#  REECA1_87  | zl   | 0           | 0.900
#  REECA1_88  | zl   | 0.002       | 0.900
#  REECA1_89  | zl   | 0           | 0.900
#  REECA1_90  | zl   | -0.095      | 0.900
#  REECA1_92  | zl   | -0.104      | 0.900
#  REECA1_93  | zl   | 0.005       | 0.900
#  REECA1_94  | zl   | -0.061      | 0.900
#  REECA1_95  | zl   | -0.000      | 0.900
#  REECA1_96  | zl   | 0.002       | 0.900
#  REECA1_97  | zl   | 0.005       | 0.900
#  REECA1_98  | zl   | -0.576      | 0.900
#  REECA1_99  | zl   | 0           | 0.900
#  REECA1_100 | zl   | 0.131       | 0.900
#  REECA1_101 | zl   | -3.833      | 0.900
#  REECA1_102 | zl   | 0           | 0.900
#  REECA1_103 | zl   | 0.280       | 0.900
#  REECA1_104 | zl   | 0.522       | 0.900
#  REECA1_105 | zl   | 0.406       | 0.900
#  REECA1_106 | zl   | 0           | 0.900
#  REECA1_107 | zl   | 0.031       | 0.900
#  REECA1_108 | zl   | 0.005       | 0.900
#  REECA1_109 | zl   | -0.138      | 0.900
#  REECA1_110 | zl   | 0           | 0.900
#  REECA1_111 | zl   | 0           | 0.900
#  REECA1_112 | zl   | 0           | 0.900
#  REECA1_113 | zl   | 0           | 0.900
#  REECA1_114 | zl   | -1.414      | 0.900
#  REECA1_115 | zl   | 0           | 0.900
#  REECA1_116 | zl   | 0           | 0.900
#  REECA1_117 | zl   | 0           | 0.900
#  REECA1_118 | zl   | -0.523      | 0.900
#  REECA1_119 | zl   | 0           | 0.900
#  REECA1_120 | zl   | -72.558     | 0.900
#  REECA1_121 | zl   | 0.806       | 0.900
#  REECA1_122 | zl   | 0           | 0.900
#  REECA1_123 | zl   | 0           | 0.900
#  REECA1_124 | zl   | 0           | 0.900
#  REECA1_125 | zl   | 0           | 0.900
#  REECA1_126 | zl   | 0           | 0.900
#  REECA1_127 | zl   | 0           | 0.900
#  REECA1_128 | zl   | 0           | 0.900
#  REECA1_129 | zl   | 0           | 0.900
#  REECA1_130 | zl   | 0           | 0.900
#  REECA1_131 | zl   | 0           | 0.900
#  REECA1_132 | zl   | -2.477      | 0.900
#  REECA1_133 | zl   | 0           | 0.900
#  REECA1_134 | zl   | 0.276       | 0.900
#  REECA1_135 | zl   | 0           | 0.900
#  REECA1_136 | zl   | -0.022      | 0.900
#  REECA1_137 | zl   | -0.092      | 0.900
#  REECA1_138 | zl   | 0           | 0.900
#  REECA1_139 | zl   | 0.872       | 0.900
#  REECA1_140 | zl   | 0           | 0.900
#  REECA1_141 | zl   | 0           | 0.900
#  REECA1_142 | zl   | -0.335      | 0.900
#  REECA1_143 | zl   | 0           | 0.900
#  REECA1_144 | zl   | 0           | 0.900
#  REECA1_145 | zl   | 0           | 0.900
#  REECA1_146 | zl   | 0           | 0.900
#  REECA1_147 | zl   | 0           | 0.900
#  REECA1_148 | zl   | 0           | 0.900
#  REECA1_150 | zl   | 0           | 0.900
#  REECA1_151 | zl   | 0           | 0.900
#  REECA1_152 | zl   | 0.063       | 0.900
#  REECA1_153 | zl   | 0.226       | 0.900
#  REECA1_154 | zl   | 0.336       | 0.900
#  REECA1_155 | zl   | 0           | 0.900
#  REECA1_156 | zl   | 0           | 0.900
#  REECA1_157 | zl   | -0.032      | 0.900
#  REECA1_158 | zl   | 0           | 0.900
#  REECA1_159 | zl   | 0           | 0.900
#  REECA1_160 | zl   | 0.513       | 0.900
#  REECA1_162 | zl   | -3.585      | 0.900
#  REECA1_163 | zl   | -3.286      | 0.900
#  REECA1_164 | zl   | 0           | 0.900
#  REECA1_166 | zl   | 0           | 0.900
#  REECA1_167 | zl   | -0.168      | 0.900
#  REECA1_169 | zl   | 0.532       | 0.900
#  REECA1_170 | zl   | 0           | 0.900
#  REECA1_171 | zl   | 0           | 0.900
#  REECA1_174 | zl   | 0           | 0.900
#  REECA1_175 | zl   | 0           | 0.900
#  REECA1_176 | zl   | 0           | 0.900
#  REECA1_177 | zl   | 0.150       | 0.900
#  REECA1_178 | zl   | 0.389       | 0.900
#  REECA1_179 | zl   | 0.325       | 0.900
#  REECA1_180 | zl   | 0           | 0.900
#  REECA1_181 | zl   | 0.664       | 0.900
#  REECA1_183 | zl   | -1.764      | 0.900
#  REECA1_184 | zl   | 0.351       | 0.900
#  REECA1_185 | zl   | -0.111      | 0.900
#  REECA1_187 | zl   | 0.433       | 0.900
#  REECA1_188 | zl   | 0           | 0.900
#  REECA1_190 | zl   | -0.800      | 0.900
#  REECA1_191 | zl   | 0.008       | 0.900
#  REECA1_192 | zl   | 0.000       | 0.900
#  REECA1_193 | zl   | 0.003       | 0.900
#  REECA1_194 | zl   | 0.001       | 0.900
#  REECA1_195 | zl   | 0.008       | 0.900
#  REECA1_196 | zl   | 0.004       | 0.900
#  REECA1_197 | zl   | -0.609      | 0.900
#  REECA1_198 | zl   | 0           | 0.900
#  REECA1_199 | zl   | -0.376      | 0.900
#  REECA1_202 | zl   | 0           | 0.900
#  REECA1_203 | zl   | -1.970      | 0.900
#  REECA1_204 | zl   | 0           | 0.900
#  REECA1_205 | zl   | 0.378       | 0.900
#  REECA1_206 | zl   | -0.027      | 0.900
#  REECA1_208 | zl   | -4.135      | 0.900
#  REECA1_210 | zl   | -0.072      | 0.900
#  REECA1_211 | zl   | 0           | 0.900
#  REECA1_213 | zl   | 0           | 0.900
#  REECA1_214 | zl   | -0.094      | 0.900
#  REECA1_215 | zl   | 0.093       | 0.900
#  REECA1_216 | zl   | 0           | 0.900
#  REECA1_217 | zl   | 0           | 0.900
#  REECA1_218 | zl   | 0           | 0.900
#  REECA1_219 | zl   | 0           | 0.900
#  REECA1_221 | zl   | 0.078       | 0.900
#  REECA1_222 | zl   | 0           | 0.900
#  REECA1_224 | zl   | -0.378      | 0.900
#  REECA1_225 | zl   | 0           | 0.900
#  REECA1_227 | zl   | -0.364      | 0.900
#  REECA1_228 | zl   | -0.796      | 0.900
#  REECA1_229 | zl   | -0.009      | 0.900
#  REECA1_231 | zl   | -0.201      | 0.900
#  REECA1_232 | zl   | 0.524       | 0.900
#  REECA1_233 | zl   | 0           | 0.900
#  REECA1_234 | zl   | -0.024      | 0.900
#  REECA1_235 | zl   | 0           | 0.900
#  REECA1_236 | zl   | -0.686      | 0.900
#  REECA1_237 | zl   | 0           | 0.900
#  REECA1_238 | zl   | 0.106       | 0.900
#  REECA1_239 | zl   | 0.089       | 0.900
#  REECA1_240 | zl   | 0.168       | 0.900
#  REECA1_241 | zl   | -0.573      | 0.900
#  REECA1_242 | zl   | -2.184      | 0.900
#  REECA1_243 | zl   | -0.002      | 0.900
#  REECA1_244 | zl   | 0           | 0.900
#  REECA1_245 | zl   | 0           | 0.900
#  REECA1_246 | zl   | -0.129      | 0.900
#  REECA1_248 | zl   | 0.113       | 0.900
#  REECA1_249 | zl   | -0.217      | 0.900
#  REECA1_251 | zl   | 0.854       | 0.900
#  REECA1_252 | zl   | 0.594       | 0.900
#  REECA1_253 | zl   | -5.764      | 0.900
#  REECA1_254 | zl   | -5.232      | 0.900
#  REECA1_255 | zl   | -3.210      | 0.900
#  REECA1_256 | zl   | -5.102      | 0.900
#  REECA1_257 | zl   | -0.159      | 0.900
#  REECA1_258 | zl   | 0.340       | 0.900
#  REECA1_259 | zl   | -0.182      | 0.900
#  REECA1_260 | zl   | -0.208      | 0.900
#  REECA1_261 | zl   | 0           | 0.900
#  REECA1_262 | zl   | -0.295      | 0.900
#  REECA1_263 | zl   | -0.072      | 0.900
#  REECA1_264 | zl   | -0.183      | 0.900
#  REECA1_265 | zl   | 0.298       | 0.900
#  REECA1_266 | zl   | -0.333      | 0.900
#  REECA1_267 | zl   | 0.283       | 0.900
#  REECA1_269 | zl   | -0.332      | 0.900
#  REECA1_270 | zl   | -0.305      | 0.900
#  REECA1_271 | zl   | -0.059      | 0.900
#  REECA1_272 | zl   | 0           | 0.900
#  REECA1_276 | zl   | 0.260       | 0.900
#  REECA1_277 | zl   | 0.001       | 0.900
#  REECA1_278 | zl   | 0.000       | 0.900
#  REECA1_279 | zl   | 0.001       | 0.900
#  REECA1_280 | zl   | 0.000       | 0.900
#  REECA1_281 | zl   | 0.001       | 0.900
#  REECA1_282 | zl   | -0.170      | 0.900
#  REECA1_283 | zl   | 0           | 0.900
#  REECA1_284 | zl   | 0           | 0.900
#  REECA1_286 | zl   | 0           | 0.900
#  REECA1_287 | zl   | -0.986      | 0.900
#  REECA1_288 | zl   | 0.128       | 0.900
#  REECA1_289 | zl   | 0           | 0.900
#  REECA1_290 | zl   | -0.591      | 0.900
#  REECA1_291 | zl   | -0.260      | 0.900
#  REECA1_292 | zl   | -0.178      | 0.900
#  REECA1_293 | zl   | -0.245      | 0.900
#  REECA1_294 | zl   | -0.309      | 0.900
#  REECA1_295 | zl   | -0.826      | 0.900
#  REECA1_298 | zl   | 0.877       | 0.900
#  REECA1_299 | zl   | -0.153      | 0.900
#  REECA1_300 | zl   | 0.737       | 0.900
#  REECA1_301 | zl   | 0           | 0.900
#  REECA1_302 | zl   | -0.466      | 0.900
#
#
# REECA1.Vsel_lim out of limits <VMIN>
#
#     idx     | Flag | Input Value | Limit
# ------------+------+-------------+------
#  REECA1_211 | zl   | -5.282      | 0.900
#
#
# REECA1.dbV_db out of limits <dbd1>
#
#     idx     | Flag | Input Value | Limit
# ------------+------+-------------+------
#  REECA1_1   | zl   | -1.010      | 0
#  REECA1_2   | zl   | -1          | 0
#  REECA1_3   | zl   | -1          | 0
#  REECA1_4   | zl   | -1          | 0
#  REECA1_5   | zl   | -1          | 0
#  REECA1_6   | zl   | -1          | 0
#  REECA1_7   | zl   | -1          | 0
#  REECA1_8   | zl   | -1          | 0
#  REECA1_9   | zl   | -1          | 0
#  REECA1_10  | zl   | -1.010      | 0
#  REECA1_11  | zl   | -1.010      | 0
#  REECA1_12  | zl   | -1          | 0
#  REECA1_13  | zl   | -1          | 0
#  REECA1_14  | zl   | -1          | 0
#  REECA1_15  | zl   | -1          | 0
#  REECA1_16  | zl   | -1          | 0
#  REECA1_17  | zl   | -1          | 0
#  REECA1_18  | zl   | -1          | 0
#  REECA1_19  | zl   | -1          | 0
#  REECA1_20  | zl   | -1          | 0
#  REECA1_21  | zl   | -1          | 0
#  REECA1_22  | zl   | -1          | 0
#  REECA1_23  | zl   | -1          | 0
#  REECA1_24  | zl   | -1          | 0
#  REECA1_25  | zl   | -1          | 0
#  REECA1_26  | zl   | -1.004      | 0
#  REECA1_27  | zl   | -1          | 0
#  REECA1_28  | zl   | -1          | 0
#  REECA1_29  | zl   | -1          | 0
#  REECA1_30  | zl   | -1          | 0
#  REECA1_31  | zl   | -1.017      | 0
#  REECA1_32  | zl   | -1          | 0
#  REECA1_33  | zl   | -1.010      | 0
#  REECA1_34  | zl   | -1.010      | 0
#  REECA1_35  | zl   | -1.010      | 0
#  REECA1_36  | zl   | -1.010      | 0
#  REECA1_37  | zl   | -1          | 0
#  REECA1_38  | zl   | -1.040      | 0
#  REECA1_39  | zl   | -1          | 0
#  REECA1_40  | zl   | -1          | 0
#  REECA1_41  | zl   | -1          | 0
#  REECA1_42  | zl   | -1.040      | 0
#  REECA1_43  | zl   | -1          | 0
#  REECA1_44  | zl   | -1          | 0
#  REECA1_45  | zl   | -1          | 0
#  REECA1_46  | zl   | -1          | 0
#  REECA1_47  | zl   | -1          | 0
#  REECA1_48  | zl   | -1          | 0
#  REECA1_49  | zl   | -1          | 0
#  REECA1_50  | zl   | -1          | 0
#  REECA1_51  | zl   | -1          | 0
#  REECA1_265 | zl   | -1          | 0
#  REECA1_266 | zl   | -1          | 0
#  REECA1_267 | zl   | -1          | 0
#  REECA1_268 | zl   | -1          | 0
#  REECA1_269 | zl   | -1.040      | 0
#  REECA1_270 | zl   | -1.040      | 0
#  REECA1_271 | zl   | -1.040      | 0
#  REECA1_272 | zl   | -1.018      | 0
#  REECA1_273 | zl   | -1          | 0
#  REECA1_274 | zl   | -1          | 0
#  REECA1_275 | zl   | -1          | 0
#  REECA1_276 | zl   | -1          | 0
#  REECA1_277 | zl   | -1          | 0
#  REECA1_278 | zl   | -1          | 0
#  REECA1_279 | zl   | -1          | 0
#  REECA1_280 | zl   | -1          | 0
#  REECA1_281 | zl   | -1          | 0
#  REECA1_282 | zl   | -1          | 0
#  REECA1_283 | zl   | -1          | 0
#  REECA1_284 | zl   | -1          | 0
#  REECA1_285 | zl   | -1          | 0
#  REECA1_286 | zl   | -1          | 0
#  REECA1_287 | zl   | -1          | 0
#  REECA1_288 | zl   | -1          | 0
# ...
#  Ipmax REECA1 296  | 15.030     | -0.067
#  Ipmax REECA1 297  | 28.291     | 0.007
#  Ipmax REECA1 298  | 2.673      | -0.334
#  Ipmax REECA1 299  | 0.681      | -0.681
#  Ipmax REECA1 300  | 13.142     | -0.057
#  Ipmax REECA1 301  | 4.836      | 0.026
#  Ipmax REECA1 302  | 1.775      | -0.122
#  Iqmax REECA1 1    | 0.381      | -0.381
#  Iqmax REECA1 2    | 1.261      | -1.261
#  Iqmax REECA1 3    | 2.335      | -2.335
#  Iqmax REECA1 5    | 0.532      | -0.532
#  Iqmax REECA1 6    | 1.056      | -1.056
#  Iqmax REECA1 7    | 1.416      | -1.416
#  Iqmax REECA1 8    | 1.996      | -1.996
#  Iqmax REECA1 9    | 0.600      | -0.600
#  Iqmax REECA1 10   | 0.194      | -0.194
#  Iqmax REECA1 11   | 1.724      | -1.724
#  Iqmax REECA1 13   | 0.371      | -0.371
#  Iqmax REECA1 14   | 3.558      | -3.558
#  Iqmax REECA1 16   | 0.513      | -0.513
#  Iqmax REECA1 17   | 2.738      | -2.738
#  Iqmax REECA1 19   | 2.601      | -2.601
#  Iqmax REECA1 21   | 1.839      | -1.839
#  Iqmax REECA1 22   | 2.831      | -2.831
#  Iqmax REECA1 25   | 0.804      | -0.804
#  Iqmax REECA1 27   | 1.825      | -1.825
#  Iqmax REECA1 29   | 1.102      | -1.102
#  Iqmax REECA1 30   | 0.061      | -0.061
#  Iqmax REECA1 37   | 0.264      | -0.264
#  Iqmax REECA1 38   | 1.982      | -1.982
#  Iqmax REECA1 41   | 2.871      | -2.871
#  Iqmax REECA1 42   | 1.222      | -1.222
#  Iqmax REECA1 44   | 2.553      | -2.553
#  Iqmax REECA1 45   | 2.073      | -2.073
#  Iqmax REECA1 46   | 1.801      | -1.801
#  Iqmax REECA1 47   | 1.086      | -1.086
#  Iqmax REECA1 48   | 2.436      | -2.436
#  Iqmax REECA1 49   | 1.480      | -1.480
#  Iqmax REECA1 50   | 1.971      | -1.971
#  Iqmax REECA1 51   | 2.954      | -2.954
#  Iqmax REECA1 276  | 2.154      | -2.154
#  Iqmax REECA1 277  | 2.429      | -2.429
#  Iqmax REECA1 278  | 2.069      | -2.069
#  Iqmax REECA1 279  | 0.539      | -0.539
#  Iqmax REECA1 280  | 0.810      | -0.810
#  Iqmax REECA1 281  | 1.709      | -1.709
#  Iqmax REECA1 282  | 0.873      | -0.873
#  Iqmax REECA1 284  | 0.202      | -0.202
#  Iqmax REECA1 285  | 0.087      | -0.087
#  Iqmax REECA1 286  | 0.058      | -0.058
#  Iqmax REECA1 287  | 2.899      | -2.899
#  Iqmax REECA1 288  | 0.667      | -0.667
#  Iqmax REECA1 290  | 1.672      | -1.672
#  Iqmax REECA1 291  | 1.450      | -1.450
#  Iqmax REECA1 292  | 1.377      | -1.377
#  Iqmax REECA1 293  | 1.459      | -1.459
#  Iqmax REECA1 294  | 1.102      | -1.102
#  Iqmax REECA1 295  | 2.014      | -2.014
#  Iqmax REECA1 296  | 1.490      | -1.490
#  Iqmax REECA1 298  | 1.345      | -1.345
#  Iqmax REECA1 299  | 1.344      | -1.344
#  Iqmax REECA1 300  | 1.269      | -1.269
#  Iqmax REECA1 302  | 0.656      | -0.656
#  IpHL_x REECA1 1   | 1.567      | -0.577
#  IpHL_x REECA1 3   | 1.444      | -0.444
#  IpHL_x REECA1 6   | 2.930      | -1.930
#  IpHL_x REECA1 7   | 2.930      | -1.930
#  IpHL_x REECA1 8   | 1.496      | -0.496
#  IpHL_x REECA1 10  | 1.337      | -0.347
#  IpHL_x REECA1 11  | 1.337      | -0.347
#  IpHL_x REECA1 14  | 1.692      | -0.692
#  IpHL_x REECA1 17  | 1.394      | -0.394
#  IpHL_x REECA1 18  | 2.085      | -1.085
#  IpHL_x REECA1 19  | 2.085      | -1.085
#  IpHL_x REECA1 23  | 1.106      | -0.106
#  IpHL_x REECA1 29  | 4.574      | -3.574
#  IpHL_x REECA1 37  | 1.069      | -0.069
#  IpHL_x REECA1 38  | 1.157      | -0.196
#  IpHL_x REECA1 39  | 1.125      | -0.125
#  IpHL_x REECA1 50  | 1.051      | -0.051
#  IpHL_x REECA1 53  | 1.504      | -0.504
#  IpHL_x REECA1 54  | 1.504      | -0.504
#  IpHL_x REECA1 60  | 2.413      | -1.413
#  IpHL_x REECA1 69  | 3.270      | -2.270
#  IpHL_x REECA1 72  | 0.996      | -0.015
#  IpHL_x REECA1 75  | 1.125      | -0.125
#  IpHL_x REECA1 89  | 1.103      | -0.123
#  IpHL_x REECA1 99  | 1.363      | -0.363
#  IpHL_x REECA1 100 | 1.363      | -0.363
#  IpHL_x REECA1 101 | 2.081      | -1.120
#  IpHL_x REECA1 109 | 1.259      | -0.269
#  IpHL_x REECA1 110 | 1.092      | -0.121
#  IpHL_x REECA1 112 | 1.442      | -0.481
#  IpHL_x REECA1 114 | 1.507      | -0.546
#  IpHL_x REECA1 120 | 1.738      | -0.776
#  IpHL_x REECA1 124 | 1.768      | -0.807
#  IpHL_x REECA1 125 | 1.768      | -0.807
#  IpHL_x REECA1 126 | 1.768      | -0.807
#  IpHL_x REECA1 127 | 1.194      | -0.233
#  IpHL_x REECA1 128 | 1.194      | -0.233
#  IpHL_x REECA1 129 | 1.194      | -0.233
#  IpHL_x REECA1 130 | 1.194      | -0.233
#  IpHL_x REECA1 132 | 1.019      | -0.019
#  IpHL_x REECA1 133 | 1.082      | -0.120
#  IpHL_x REECA1 134 | 1.276      | -0.276
#  IpHL_x REECA1 138 | 1.796      | -0.834
#  IpHL_x REECA1 139 | 1.744      | -0.744
#  IpHL_x REECA1 142 | 1.442      | -0.481
#  IpHL_x REECA1 144 | 1.154      | -0.192
#  IpHL_x REECA1 149 | 1.917      | -0.917
#  IpHL_x REECA1 153 | 1.478      | -0.478
#  IpHL_x REECA1 155 | 1.012      | -0.012
#  IpHL_x REECA1 156 | 1.012      | -0.012
#  IpHL_x REECA1 157 | 1.012      | -0.012
#  IpHL_x REECA1 160 | 1.921      | -0.921
#  IpHL_x REECA1 161 | 1.921      | -0.921
#  IpHL_x REECA1 172 | 1.707      | -0.707
#  IpHL_x REECA1 174 | 1.468      | -0.497
#  IpHL_x REECA1 178 | 1.525      | -0.525
#  IpHL_x REECA1 179 | 1.525      | -0.525
#  IpHL_x REECA1 180 | 1.500      | -0.500
#  IpHL_x REECA1 182 | 2.549      | -1.549
#  IpHL_x REECA1 184 | 1.811      | -0.811
#  IpHL_x REECA1 185 | 1.337      | -0.347
#  IpHL_x REECA1 188 | 2.848      | -1.848
#  IpHL_x REECA1 197 | 1.356      | -0.394
#  IpHL_x REECA1 199 | 2.042      | -1.081
#  IpHL_x REECA1 200 | 1.508      | -0.508
#  IpHL_x REECA1 201 | 2.252      | -1.252
#  IpHL_x REECA1 202 | 1.082      | -0.120
#  IpHL_x REECA1 203 | 1.443      | -0.481
#  IpHL_x REECA1 204 | 1.478      | -0.507
#  IpHL_x REECA1 205 | 1.233      | -0.233
#  IpHL_x REECA1 207 | 4.933      | -3.933
#  IpHL_x REECA1 208 | 1.482      | -0.502
#  IpHL_x REECA1 220 | 1.580      | -0.580
#  IpHL_x REECA1 222 | 2.178      | -1.178
#  IpHL_x REECA1 225 | 2.083      | -1.083
#  IpHL_x REECA1 233 | 1.125      | -0.125
#  IpHL_x REECA1 235 | 1.688      | -0.688
#  IpHL_x REECA1 236 | 1.125      | -0.125
#  IpHL_x REECA1 238 | 2.609      | -1.609
#  IpHL_x REECA1 240 | 2.564      | -1.564
#  IpHL_x REECA1 244 | 1.194      | -0.233
#  IpHL_x REECA1 245 | 1.194      | -0.233
#  IpHL_x REECA1 249 | 2.230      | -1.230
#  IpHL_x REECA1 267 | 1.340      | -0.340
#  IpHL_x REECA1 273 | 3.525      | -2.525
#  IpHL_x REECA1 296 | 2.776      | -1.776
#  IpHL_x REECA1 297 | 5.224      | -4.224
#  IpHL_x REECA1 300 | 2.427      | -1.427
#
#
# Initialization failed!!
# If you are developing a new model, check the initialization with
#    andes -v 10 run -r tds --init Texas2k/Texas2k_v33.raw
# Otherwise, check the variables that are initialized out of limits.
